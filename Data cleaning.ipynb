# %%
#importing the important libraries
import numpy as np
import pandas as pd
# pd.set_option('display.max_colwidth', -1)
# pd.set_option('display.max_rows', None)

# %%
#loading the datasets into a dataframe
korean = pd.read_csv('KoreanMovies.csv')
thailand = pd.read_csv('ThaiLandMovies.csv')
chinese = pd.read_csv('ChineseMovies.csv')
hongkong =pd.read_csv('HongKongMovies.csv')

# %%
#concatenating all the dataframes since they have the same columns
asian_df = pd.concat([korean, thailand, chinese, hongkong])

# %%
#checking out the first 5 rows of the dataframe
asian_df.head()
# Out:
#                                   Title              Rating  \
# 0               Amazing Saturday (2018)  Three & Half Stars
# 1  I Can See Your Voice Season 9 (2022)         Three Stars
# 2    Omniscient Interfering View (2017)         Three Stars
# 3              Mr. House Husband (2016)         Three Stars
# 4     The Game Caterers Season 2 (2022)          Four Stars
#
#                                                Genre  \
# 0  Drama , Comedy , Drama , Food , Music , Korean...
# 1  Drama , Kshow , Music , Mystery , Korean | Epi...
# 2  Drama , Game-Show , Kshow , Korean | Episodes 200
# 3  Drama , Drama , Family , Food , Kshow , Korean...
# 4    Drama , Business , Kshow , Korean | Episodes 12
#
#                                          Description   Release year  \
# 0  The poster shows Shin Dong Yup, Girl’s Day’s H...  Release: 2018
# 1  I Can See Your Voice” is a mystery music game ...  Release: 2022
# 2  The managers, who know more about the stars th...  Release: 2017
# 3  Dear valued customer, 1. Dramacool regularly u...  Release: 2016
# 4  A business trip program with PD Na Young Seok....  Release: 2022
#
#                                                Casts Country
# 0  {'Shin Dong Yup\nRegular Member', 'Key\nRegula...  Korean
# 1  {'', 'Ha Sung Woon\nGuest', 'Guest', 'Lee Teuk...  Korean
# 2                                      not available  Korean
# 3  {'Kim Eli\nGuest', 'Lee Chul Min\nGuest', 'Son...  Korean
# 4  {'', 'Im Ji Yeon\nGuest', 'Lee Seo Jin\nGuest'...  Korean

# %%
#checking the shape of the dataframe
asian_df.shape
# Out:
# (5854, 7)

# %%
#checking for null values in the dataframe
asian_df.isna().sum()
# Out:
# Title              0
# Rating             0
# Genre              0
# Description        3
# Release year    5329
# Casts              0
# Country            0
# dtype: int64

# %%
#dropping duplicated values in the dataframe
asian_df = asian_df.drop_duplicates()
#checking the shape of the dataframe again
asian_df.shape
# Out:
# (5628, 7)

# %%
#getting a column named episodes from the genre column and also cleaning the episodes column.
asian_df['Episodes'] = asian_df['Genre'].apply(lambda x: str(x).split('|')[-1])
asian_df['Genre'] = asian_df['Genre'].apply(lambda x: str(x).split('|')[0])
asian_df['Episodes'] = asian_df['Episodes'].replace(r'(\D)', '', regex=True)

# %%
#getting the year column from the title column and also cleaning the year and title column
asian_df['Year'] = asian_df['Title'].apply(lambda x: str(x).split('(')[-1])
asian_df['Year'] = asian_df['Year'].apply(lambda x: str(x).split(')')[0])
asian_df['Title'] = asian_df['Title'].replace(r'(\d\d\d\d)', '', regex=True)
asian_df['Title']= asian_df['Title'].replace(r'(\(\))', '', regex=True)

# %%
#cleaning the rating column by converting all the words to numbers
asian_df['Rating'] = asian_df['Rating'].replace(r'(\&)', '.5', regex=True)
asian_df['Rating'] = asian_df['Rating'].str.replace('Half', '')
asian_df['Rating'] = asian_df['Rating'].str.replace('Stars', '')
asian_df['Rating'] = asian_df['Rating'].str.replace('Star', '')
asian_df['Rating'] = asian_df['Rating'].str.replace('Three', '3')
asian_df['Rating'] = asian_df['Rating'].str.replace('Two', '2')
asian_df['Rating'] = asian_df['Rating'].str.replace('One', '1')
asian_df['Rating'] = asian_df['Rating'].str.replace('Four', '4')
asian_df['Rating'] = asian_df['Rating'].str.replace('Five', '5')
asian_df['Rating'] = asian_df['Rating'].str.replace(' ', '')
asian_df['Rating'] = asian_df['Rating'].str.replace('NotRated', '0')

# %%
#checking for unique values in the rating column to ensure it is now clean.
asian_df['Rating'].unique()
# Out:
# array(['3.5', '3', '4', '0', '4.5', '2.5', '2', '1.5', '1', '5'],
#       dtype=object)

# %%
#replcing symbols with empty soace
asian_df['Casts'] = asian_df['Casts'].replace(r'(\\n)', ':', regex=True)
asian_df['Casts'] = asian_df['Casts'].replace(r"['\{|\}|\"|:]", '', regex=True)
#replacing the role each actor played & some unwanted values  with an empty string
asian_df.Casts = asian_df['Casts'].str.replace('Regular Member', '')
asian_df.Casts = asian_df['Casts'].str.replace('Guest', '')
asian_df.Casts = asian_df['Casts'].str.replace('Main Host', '')
asian_df.Casts = asian_df['Casts'].str.replace('supporting role', '')
asian_df.Casts = asian_df['Casts'].str.replace('main role', '')
asian_df.Casts = asian_df['Casts'].str.replace('role', '')
asian_df.Casts = asian_df['Casts'].str.replace('/', '')
asian_df.Casts = asian_df['Casts'].str.replace(r'(\(.*?\))', '', regex=True)
asian_df.Casts = asian_df['Casts'].str.replace(r'\[[^()]*\]', '', regex=True)

# %%
#converting all description, casts entries to lowercase
asian_df['Description'] = asian_df['Description'].astype(str).apply(lambda x: x.lower())
asian_df['Casts'] = asian_df['Casts'].astype(str).apply(lambda x: x.lower())
asian_df['Genre'] = asian_df['Genre'].astype(str).apply(lambda x: x.lower())
asian_df['Country'] = asian_df['Country'].astype(str).apply(lambda x: x.lower())
#removing punctuations from the description column
asian_df['Description'] = asian_df['Description'].replace(r'[^\w\s\$]', '', regex=True)

# %%
asian_df.loc[(asian_df.Casts == "not available")]
# Out:
#                             Title Rating  \
# 2    Omniscient Interfering View       3
# 6               How Do You Play?       3
# 7                 Fun Restaurant       3
# 8                   I Live Alone       3
# 9                Ask Us Anything     3.5
# ..                            ...    ...
# 141                   Oh My Grad       3
# 143                         OCTB       3
# 150                News Magazine     3.5
# 191   Vampire Cleanup Department       3
# 196                Burning Hands       3
#
#                                                  Genre  \
# 2                  drama , game-show , kshow , korean
# 6                              drama , kshow , korean
# 7                              drama , kshow , korean
# 8                  drama , game-show , kshow , korean
# 9                  drama , game-show , kshow , korean
# ..                                                 ...
# 141                               drama , comedy , hk
# 143                               drama , comedy , hk
# 150                             drama , game-show , hk
# 191  movie , action , comedy , horror , supernatura...
# 196                     drama , crime , thriller , hk
#
#                                            Description   Release year  \
# 2    the managers who know more about the stars the...  Release: 2017
# 6    one of the best mcs in the country yu jae seok...  Release: 2019
# 7    fun restaurant is a new variety show where cel...  Release: 2019
# 8    with the number of singleperson households eve...  Release: 2013
# 9    the brother 아는 님 认 is a korean reality show va...  Release: 2016
# ..                                                 ...            ...
# 141  he winds up returning to the rundown college t...            NaN
# 143  undercover detective chen fengxiang in a crack...            NaN
# 150  高清翡翠台周六及周日黃金時段會有全新組合全新安排 無線電視新聞部製作的新聞透視及星期日檔案節...            NaN
# 191  attacked by vampire spring a born loser is sav...            NaN
# 196  yat gor chak koonyat win jeh ho chingfa and ye...            NaN
#
#              Casts   Country Episodes  Year
# 2    not available    korean      200  2017
# 6    not available    korean      100  2019
# 7    not available    korean      100  2019
# 8    not available    korean      500  2013
# 9    not available    korean      300  2016
# ..             ...       ...      ...   ...
# 141  not available  hongkong       30  2017
# 143  not available  hongkong       30  2017
# 150  not available  hongkong           2017
# 191  not available  hongkong       93  2017
# 196  not available  hongkong       28  2017
#
# [1256 rows x 9 columns]

# %%
#replacing the not available column with null values
asian_df.loc[(asian_df.Casts == 'not available'), 'Casts'] = ''
asian_df.loc[(asian_df.Casts == "not available")]
# Out:
# Empty DataFrame
# Columns: [Title, Rating, Genre, Description, Release year, Casts, Country, Episodes, Year]
# Index: []

# %%
asian_df['Year'].unique()
# Out:
# array(['2018', '2022', '2017', '2016', '2019', '2013', '2021', '2020',
#        '2011', '2015', '2012', '2005', '2010', '2003', '2009', '2008',
#        '2006', '2007', '2014', '2004', '1997', '1999', 'Little Bird',
#        '2002', '2001', '1998', '1995', 'Hall of Comedy - The Beginning',
#        '1996', '1984', '1993', '2000', 'Views', 'Upcoming Dramas', '1994',
#        '1982', '1985', '1987', '1992', '1990', '1980', '1965', '1986',
#        '1976', '1988', '1989', 'Legend of The Raiders', '1979', '1981'],
#       dtype=object)

# %%
asian_df['Year'] = asian_df['Year'].replace(('Hall of Comedy - The Beginning', 'Views', 'Upcoming Dramas', 'Legend of The Raiders', 'Little Bird'),
                                    (np.nan, np.nan, np.nan, np.nan, np.nan))

# %%
#filling the year column with 2021 and converting to integer. 2021 is the max year
asian_df['Year'].fillna('2021', inplace=True)
#converting the numeric column to their right datatype
asian_df['Rating'] = pd.to_numeric(asian_df['Rating'])
#asian_df['Episodes'] = asian_df['Episodes'].astype(int)
asian_df['Year'] = asian_df['Year'].astype(int)

# %%
#checking out the first 5 rows of the dataframe
asian_df.head()
# Out:
#                             Title  Rating  \
# 0               Amazing Saturday      3.5
# 1  I Can See Your Voice Season 9      3.0
# 2    Omniscient Interfering View      3.0
# 3              Mr. House Husband      3.0
# 4     The Game Caterers Season 2      4.0
#
#                                              Genre  \
# 0  drama , comedy , drama , food , music , korean
# 1        drama , kshow , music , mystery , korean
# 2              drama , game-show , kshow , korean
# 3  drama , drama , family , food , kshow , korean
# 4               drama , business , kshow , korean
#
#                                          Description   Release year  \
# 0  the poster shows shin dong yup girls days hyer...  Release: 2018
# 1  i can see your voice is a mystery music game s...  Release: 2022
# 2  the managers who know more about the stars the...  Release: 2017
# 3  dear valued customer 1 dramacool regularly upd...  Release: 2016
# 4  a business trip program with pd na young seok ...  Release: 2022
#
#                                                Casts Country Episodes  Year
# 0             shin dong yup, key, park na rae, hyeri  korean      100  2018
# 1  , ha sung woon, , lee teuk, yoo se yoon, lee h...  korean       10  2022
# 2                                                     korean      200  2017
# 3  kim eli, lee chul min, son tae young, kim jung...  korean      200  2016
# 4  , im ji yeon, lee seo jin, jung hyung suk, lee...  korean       12  2022

# %%
asian_df.fillna("", inplace=True)

# %%
asian_df.dtypes
# Out:
# Title            object
# Rating          float64
# Genre            object
# Description      object
# Release year     object
# Casts            object
# Country          object
# Episodes         object
# Year              int32
# dtype: object

# %%
asian_df.isna().sum()
# Out:
# Title           0
# Rating          0
# Genre           0
# Description     0
# Release year    0
# Casts           0
# Country         0
# Episodes        0
# Year            0
# dtype: int64

# %%
asian_df['Genre'] = asian_df['Genre'].str.split(',')
asian_df['Genre1'] = asian_df['Genre'].apply(lambda x: x[0])

# Some of the movies have only one genre. In such cases, assign the same genre to 'genre_2' as well
asian_df['Genre2'] = asian_df['Genre'].apply(lambda x: x[1] if len(x) > 1 else x[0])
asian_df['Genre3'] = asian_df['Genre'].apply(lambda x: x[2] if len(x) > 2 else x[0])
asian_df['Genre4'] = asian_df['Genre'].apply(lambda x: x[3] if len(x) > 3 else x[0])
asian_df['Genre5'] = asian_df['Genre'].apply(lambda x: x[4] if len(x) > 4 else x[0])
asian_df['Genre6'] = asian_df['Genre'].apply(lambda x: x[5] if len(x) > 5 else x[0])

# %%
asian_df.head()
# Out:
#                             Title  Rating  \
# 0               Amazing Saturday      3.5
# 1  I Can See Your Voice Season 9      3.0
# 2    Omniscient Interfering View      3.0
# 3              Mr. House Husband      3.0
# 4     The Game Caterers Season 2      4.0
#
#                                                Genre  \
# 0  [drama ,  comedy ,  drama ,  food ,  music ,  ...
# 1    [drama ,  kshow ,  music ,  mystery ,  korean ]
# 2           [drama ,  game-show ,  kshow ,  korean ]
# 3  [drama ,  drama ,  family ,  food ,  kshow ,  ...
# 4            [drama ,  business ,  kshow ,  korean ]
#
#                                          Description   Release year  \
# 0  the poster shows shin dong yup girls days hyer...  Release: 2018
# 1  i can see your voice is a mystery music game s...  Release: 2022
# 2  the managers who know more about the stars the...  Release: 2017
# 3  dear valued customer 1 dramacool regularly upd...  Release: 2016
# 4  a business trip program with pd na young seok ...  Release: 2022
#
#                                                Casts Country Episodes  Year  \
# 0             shin dong yup, key, park na rae, hyeri  korean      100  2018
# 1  , ha sung woon, , lee teuk, yoo se yoon, lee h...  korean       10  2022
# 2                                                     korean      200  2017
# 3  kim eli, lee chul min, son tae young, kim jung...  korean      200  2016
# 4  , im ji yeon, lee seo jin, jung hyung suk, lee...  korean       12  2022
#
#    Genre1       Genre2    Genre3     Genre4    Genre5    Genre6
# 0  drama       comedy     drama       food     music    korean
# 1  drama        kshow     music    mystery    korean     drama
# 2  drama    game-show     kshow     korean     drama     drama
# 3  drama        drama    family       food     kshow    korean
# 4  drama     business     kshow     korean     drama     drama

# %%
asian_df['Casts'] = asian_df['Casts'].str.lstrip(',')

# %%
asian_df.head()
# Out:
#                             Title  Rating  \
# 0               Amazing Saturday      3.5
# 1  I Can See Your Voice Season 9      3.0
# 2    Omniscient Interfering View      3.0
# 3              Mr. House Husband      3.0
# 4     The Game Caterers Season 2      4.0
#
#                                                Genre  \
# 0  [drama ,  comedy ,  drama ,  food ,  music ,  ...
# 1    [drama ,  kshow ,  music ,  mystery ,  korean ]
# 2           [drama ,  game-show ,  kshow ,  korean ]
# 3  [drama ,  drama ,  family ,  food ,  kshow ,  ...
# 4            [drama ,  business ,  kshow ,  korean ]
#
#                                          Description   Release year  \
# 0  the poster shows shin dong yup girls days hyer...  Release: 2018
# 1  i can see your voice is a mystery music game s...  Release: 2022
# 2  the managers who know more about the stars the...  Release: 2017
# 3  dear valued customer 1 dramacool regularly upd...  Release: 2016
# 4  a business trip program with pd na young seok ...  Release: 2022
#
#                                                Casts Country Episodes  Year  \
# 0             shin dong yup, key, park na rae, hyeri  korean      100  2018
# 1   ha sung woon, , lee teuk, yoo se yoon, lee hy...  korean       10  2022
# 2                                                     korean      200  2017
# 3  kim eli, lee chul min, son tae young, kim jung...  korean      200  2016
# 4   im ji yeon, lee seo jin, jung hyung suk, lee ...  korean       12  2022
#
#    Genre1       Genre2    Genre3     Genre4    Genre5    Genre6
# 0  drama       comedy     drama       food     music    korean
# 1  drama        kshow     music    mystery    korean     drama
# 2  drama    game-show     kshow     korean     drama     drama
# 3  drama        drama    family       food     kshow    korean
# 4  drama     business     kshow     korean     drama     drama

# %%
asian_df['Casts'] = asian_df['Casts'].str.split(',')
asian_df['Cast1'] = asian_df['Casts'].apply(lambda x: x[0])

# Some of the movies have only one genre. In such cases, assign the same genre to 'genre_2' as well
asian_df['Cast2'] = asian_df['Casts'].apply(lambda x: x[1] if len(x) > 1 else x[0])
asian_df['Cast3'] = asian_df['Casts'].apply(lambda x: x[2] if len(x) > 2 else x[0])
asian_df['Cast4'] = asian_df['Casts'].apply(lambda x: x[3] if len(x) > 3 else x[0])
asian_df['Cast5'] = asian_df['Casts'].apply(lambda x: x[4] if len(x) > 4 else x[0])
asian_df['Cast6'] = asian_df['Casts'].apply(lambda x: x[5] if len(x) > 5 else x[0])

# %%
asian_df.isna().sum()
# Out:
# Title           0
# Rating          0
# Genre           0
# Description     0
# Release year    0
# Casts           0
# Country         0
# Episodes        0
# Year            0
# Genre1          0
# Genre2          0
# Genre3          0
# Genre4          0
# Genre5          0
# Genre6          0
# Cast1           0
# Cast2           0
# Cast3           0
# Cast4           0
# Cast5           0
# Cast6           0
# dtype: int64

# %%
asian_df.drop(['Release year', 'Casts', 'Genre'], inplace=True, axis=1)

# %%
#saving to a new csv file
asian_df.to_csv("cleanedmovies.csv", index=False)
